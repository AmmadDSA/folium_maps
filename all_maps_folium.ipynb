# %%
import folium
from folium import plugins
import ipywidgets
import geocoder
import geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds

# %% [markdown]
# https://python-visualization.github.io/folium/modules.html

# %% [markdown]
# ### Basic Maps

# %%
#  Basic map
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87aef64c1e1c903a656f7697a9be18ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87aef64c1e1c903a656f7697a9be18ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_87aef64c1e1c903a656f7697a9be18ca = L.map(
#                 &quot;map_87aef64c1e1c903a656f7697a9be18ca&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a450842bd2cfd2438044d4a59a7d715c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_87aef64c1e1c903a656f7697a9be18ca);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Initiate map at location, set zoom level, map dimentions and scale(on/off)

map1 = folium.Map(location=[43.78029817416683, -79.41590585153362], zoom_start=12, width=500, height=300, 
                  control_scale=True)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20f54bdaf00cf82611fee31c5052e5e0 {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20f54bdaf00cf82611fee31c5052e5e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_20f54bdaf00cf82611fee31c5052e5e0 = L.map(
#                 &quot;map_20f54bdaf00cf82611fee31c5052e5e0&quot;,
#                 {
#                     center: [43.78029817416683, -79.41590585153362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_20f54bdaf00cf82611fee31c5052e5e0);
#
#
#
#
#
#             var tile_layer_75b715abeba5c255b706e502b0887a77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20f54bdaf00cf82611fee31c5052e5e0);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from branca.element import Figure

# https://python-visualization.github.io/branca/element.html#element

fig = Figure(width=500, height=300)
fig.add_child(map1)
fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20f54bdaf00cf82611fee31c5052e5e0 {
#                     position: relative;
#                     width: 500.0px;
#                     height: 300.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20f54bdaf00cf82611fee31c5052e5e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_20f54bdaf00cf82611fee31c5052e5e0 = L.map(
#                 &quot;map_20f54bdaf00cf82611fee31c5052e5e0&quot;,
#                 {
#                     center: [43.78029817416683, -79.41590585153362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_20f54bdaf00cf82611fee31c5052e5e0);
#
#
#
#
#
#             var tile_layer_75b715abeba5c255b706e502b0887a77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20f54bdaf00cf82611fee31c5052e5e0);
#
# &lt;/script&gt;" width="500" height="300"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# ### Save Map

# %%
map2 = folium.Map(location=[43.78029817416683, -79.41590585153362], zoom_start=8)

# put in path.html
map2.save('maps_out/map2.html')

# %% [markdown]
# ### Map Types

# %% [markdown]
# IPYWidgets

# %%
# show map types using ipywidgets

# widget
select_widget=ipywidgets.Select(
    options=['Open Street Map', 'Terrain', 'Toner', 'Watercolor', 'Positron', 'Dark Matter'],
    value='Open Street Map',
    description='Map Type:',
    disabled=False)

# widget function
def select(map_type):
    if map_type == 'Open Street Map':
        display(folium.Map(location=[43.78029, -79.41590], zoom_start=12, height=500))
    if map_type == 'Terrain':
        display(folium.Map(location=[43.78029, -79.41590], tiles='Stamen Terrain', zoom_start=12, height=466))
    if map_type == 'Toner':
        display(folium.Map(location=[43.78029, -79.41590], tiles='Stamen Toner', zoom_start=12, height=400))
    if map_type == 'Watercolor':
        display(folium.Map(location=[43.78029, -79.41590], tiles='Stamen Watercolor', zoom_start=12, height=400))
    if map_type == 'Positron':
        display(folium.Map(location=[43.78029, -79.41590], tiles='CartoDB Positron', zoom_start=12, height=400))
    if map_type == 'Dark Matter':
        display(folium.Map(location=[43.78029, -79.41590], tiles='CartoDB Dark_Matter', zoom_start=12, height=400))
        
# interaction between widgets and function    
ipywidgets.interact(select, map_type=select_widget)
# Out:
# interactive(children=(Select(description='Map Type:', options=('Open Street Map', 'Terrain', 'Toner', 'Waterco…
# <function __main__.select(map_type)>

# %% [markdown]
# Layer Control

# %%
# show map types using layer control

# map
map_layer_control = folium.Map(location=[43.78029, -79.41590], zoom_start=8)

# add tiles to map
folium.raster_layers.TileLayer('Open Street Map').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Terrain').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Toner').add_to(map_layer_control)
folium.raster_layers.TileLayer('Stamen Watercolor').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map_layer_control)

# add layer control to show different maps
folium.LayerControl().add_to(map_layer_control)

# display map
map_layer_control
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e504b8db2517806fb00700c97b377ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e504b8db2517806fb00700c97b377ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5e504b8db2517806fb00700c97b377ab = L.map(
#                 &quot;map_5e504b8db2517806fb00700c97b377ab&quot;,
#                 {
#                     center: [43.78029, -79.4159],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c6f7a30a9a1e3d0ef8cbc74b2c8c630 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e504b8db2517806fb00700c97b377ab);
#
#
#             var tile_layer_d614f56688ec5fa46e4230d15e204f32 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e504b8db2517806fb00700c97b377ab);
#
#
#             var tile_layer_c6922dcd4f760528126b129aff667ac2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e504b8db2517806fb00700c97b377ab);
#
#
#             var tile_layer_1839722731e55320e64d9a59d8296fc0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e504b8db2517806fb00700c97b377ab);
#
#
#             var tile_layer_0d9b05d05264bf7a1cd86f31aa99861b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e504b8db2517806fb00700c97b377ab);
#
#
#             var tile_layer_ffc7a2b2f49418212993bf3c5202d102 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quo

# %%
# mini map, scroll zoom toggle button, full screen

# map
map_with_mini = folium.Map(location=(43.78029, -79.41590), zoom_start=8)

# plugin for mini map
minimap = plugins.MiniMap(toggle_display=True)

# add minimap to map
map_with_mini.add_child(minimap)

# add scroll zoom toggler to map
plugins.ScrollZoomToggler().add_to(map_with_mini)

# add full screen button to map
plugins.Fullscreen(position='topright').add_to(map_with_mini)

# display map
map_with_mini
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0db7dca5cf042c618bcd72c8593f06bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_cc3a20735aef3913f9bf9865fda152c7 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0db7dca5cf042c618bcd72c8593f06bd&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_cc3a20735aef3913f9bf9865fda152c7&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_0db7dca5cf042c618bcd72c8593f06bd.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0db7dca5cf042c618bcd72c8593f06bd = L.map(
#                 &quot;map_0db7dca5cf042c618bcd72c8593f06bd&quot;,
#                 {
#                     center: [43.78029, -79.4159],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50a84883d00508c137a91bf8dcc18d1c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0db7dca5cf042c618bcd72c8593f06bd);
#
#
#             var tile_layer_ce01ce91470268c4f433f48c3be59c8b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_4e7c520dea8cf5e9019c0caf8c9f3d80 = new L.Control.MiniMap(
#                 tile_layer_ce01ce91470268c4f433f48c3be59c8b,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: true, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_0db7dca5cf042c618bcd72c8593f06bd.addControl(mini_map_4e7c520dea8cf5e9019c0caf8c9f3d80);
#
#
#             map_0db7dca5cf042c618bcd72c8593f06bd.scrollEnabled = true;
#
#             map_0db7dca5cf042c618bcd72c8593f06bd.toggleScroll = function() {
#                 if (this.scrollEnabled) {
#                     this.scrollEnabled = false;
#                     this.scrollWheelZoom.disable();
#                 } else {
#                     this.scrollEnabled = true;
#                     this.scrollWheelZoom.enable();
#                 }
#             };
#             map_0db7dca5cf042c618bcd72c8593f06bd.toggleScroll();
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_0db7dca5cf042c618bcd72c8593f06bd);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Markers

# %%
# geocode address and place marker on map

# map
map_zoo = folium.Map(location=[43.82371418111488, -79.18548881949839], zoom_start=14)

# get location information for address
address = geocoder.osm('2000 Meadowvale Rd, Toronto')

# address latitude and longitude
address_latlng = [address.lat, address.lng]

# add marker to map
folium.Marker(address_latlng, popup='Toronto Zoo', tooltip='click').add_to(map_zoo)

# display map
map_zoo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64cf0e65f9b662ff9ab756c58e96761a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64cf0e65f9b662ff9ab756c58e96761a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_64cf0e65f9b662ff9ab756c58e96761a = L.map(
#                 &quot;map_64cf0e65f9b662ff9ab756c58e96761a&quot;,
#                 {
#                     center: [43.82371418111488, -79.18548881949839],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8154a96a59567b168cc79799601bac70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_64cf0e65f9b662ff9ab756c58e96761a);
#
#
#             var marker_6d612d1c7d3474d7cf5a1252d48aed23 = L.marker(
#                 [43.822937, -79.1776523],
#                 {}
#             ).addTo(map_64cf0e65f9b662ff9ab756c58e96761a);
#
#
#         var popup_ab8578270c163a3456939370e6e73a8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_73854abb6b631d4a1e8a3651a6f8ef05 = $(`&lt;div id=&quot;html_73854abb6b631d4a1e8a3651a6f8ef05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Toronto Zoo&lt;/div&gt;`)[0];
#             popup_ab8578270c163a3456939370e6e73a8b.setContent(html_73854abb6b631d4a1e8a3651a6f8ef05);
#
#
#         marker_6d612d1c7d3474d7cf5a1252d48aed23.bindPopup(popup_ab8578270c163a3456939370e6e73a8b)
#         ;
#
#
#
#
#             marker_6d612d1c7d3474d7cf5a1252d48aed23.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# vega datasets
# https://github.com/vega/vega-datasets

# %%
# airports dataframe using vega_datasets
airports = vds.airports()
airports = airports[:25]
airports.head()
# Out:
#   iata                  name              city state country   latitude  \
# 0  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#     longitude
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
# multiple markers using dataframe
# there is an example below using apply function instead of loop

# create map
map_airports = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations
for (index, row) in airports.iterrows():
    folium.Marker(location=[row.loc['latitude'], row.loc['longitude']], 
                  popup=row.loc['name'] + ' ' + row.loc['city'] + ' ' + row.loc['state'], 
                  tooltip='click').add_to(map_airports)
    
# display map    
map_airports
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93dc8eb6609eff021a931fea566a2695 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93dc8eb6609eff021a931fea566a2695&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_93dc8eb6609eff021a931fea566a2695 = L.map(
#                 &quot;map_93dc8eb6609eff021a931fea566a2695&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6785c35535231bd51f980cd663836d7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#             var marker_aa3a3569101399f384829d1b54b1ecb6 = L.marker(
#                 [31.95376472, -89.23450472],
#                 {}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#         var popup_ddec5060b4c670baeeb13d5b9aa1e0ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_85de3719a8f0d8f388ebb4454343b4f4 = $(`&lt;div id=&quot;html_85de3719a8f0d8f388ebb4454343b4f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen Bay Springs MS&lt;/div&gt;`)[0];
#             popup_ddec5060b4c670baeeb13d5b9aa1e0ed.setContent(html_85de3719a8f0d8f388ebb4454343b4f4);
#
#
#         marker_aa3a3569101399f384829d1b54b1ecb6.bindPopup(popup_ddec5060b4c670baeeb13d5b9aa1e0ed)
#         ;
#
#
#
#
#             marker_aa3a3569101399f384829d1b54b1ecb6.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fddf887e25a3835a86194a739f78c6b = L.marker(
#                 [30.68586111, -95.01792778],
#                 {}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#         var popup_f1aadca3f8c74b340f93b89bdf056a4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3bc741a2c1a202aad384966576a0dd36 = $(`&lt;div id=&quot;html_3bc741a2c1a202aad384966576a0dd36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal Livingston TX&lt;/div&gt;`)[0];
#             popup_f1aadca3f8c74b340f93b89bdf056a4c.setContent(html_3bc741a2c1a202aad384966576a0dd36);
#
#
#         marker_8fddf887e25a3835a86194a739f78c6b.bindPopup(popup_f1aadca3f8c74b340f93b89bdf056a4c)
#         ;
#
#
#
#
#             marker_8fddf887e25a3835a86194a739f78c6b.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ff09f3280d157b93755a4654a4f08ca7 = L.marker(
#                 [38.94574889, -104.5698933],
#                 {}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#         var popup_660ff1741d360691c866f9974305d76c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_183c0ac9472ffbb8965467b3ce0e0fa3 = $(`&lt;div id=&quot;html_183c0ac9472ffbb8965467b3ce0e0fa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake Colorado Springs CO&lt;/div&gt;`)[0];
#             popup_660ff1741d360691c866f9974305d76c.setContent(html_183c0ac9472ffbb8965467b3ce0e0fa3);
#
#
#         marker_ff09f3280d157b93755a4654a4f08ca7.bindPopup(popup_660ff1741d360691c866f9974305d76c)
#         ;
#
#
#
#
#             marker_ff09f3280d157b93755a4654a4f08ca7.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b8188b3417ca8379245137102696eee = L.marker(
#                 [42.74134667, -78.05208056],
#                 {}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#         var popup_923e68f26a5644157244bb5a84278fb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dd0b9618a5c3d95dab19880a408a05f7 = $(`&lt;div id=&quot;html_dd0b9618a5c3d95dab19880a408a05f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw Perry NY&lt;/div&gt;`)[0];
#             popup_923e68f26a5644157244bb5a84278fb8.setContent(html_dd0b9618a5c3d95dab19880a408a05f7);
#
#
#         marker_6b8188b3417ca8379245137102696eee.bindPopup(popup_923e68f26a5644157244bb5a84278fb8)
#         ;
#
#
#
#
#             marker_6b8188b3417ca8379245137102696eee.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f6fd30428592a03fe2e9c548a094c345 = L.marker(
#                 [30.6880125, -81.90594389],
#                 {}
#             ).addTo(map_93dc8eb6609eff021a931fea566a2695);
#
#
#         var popup_b8

# %%
for (index, row) in airports.iterrows():
    print(row.loc['name'])
#     print(index,row['name'])
#     print(index,row)
# Out:
# Thigpen
# Livingston Municipal
# Meadow Lake
# Perry-Warsaw
# Hilliard Airpark
# Tishomingo County
# Gragg-Wade
# Capitol
# Columbiana County
# Memphis Memorial
# Calhoun County
# Hawley Municipal
# Griffith-Merrillville
# Gatesville - City/County
# Eureka
# Moton  Municipal
# Schaumburg
# Rolla Municipal
# Eupora Municipal
# Randall
# Jackpot/Hayden
# Dekalb County
# Gladewater Municipal
# Fitch H Beach
# Central City Municipal

# %%
# markers with apply function

# map
map_airports2 = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations using apply
airports.apply(lambda row: folium.Marker(location=[row['latitude'], row['longitude']],
                                         popup=row['name']).add_to(map_airports2), axis=1)

# display map
map_airports2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ac8b1d7f73db6216996e2e88a532c29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ac8b1d7f73db6216996e2e88a532c29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1ac8b1d7f73db6216996e2e88a532c29 = L.map(
#                 &quot;map_1ac8b1d7f73db6216996e2e88a532c29&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79b7e30d1f37c78f7da38b33658bc65f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#             var marker_84073ed39d2adda164bbf85c34e48c81 = L.marker(
#                 [31.95376472, -89.23450472],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_fae6749efe4689ddfe62c877ed677144 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_916f58b97abdd0e68e742f11ab12db68 = $(`&lt;div id=&quot;html_916f58b97abdd0e68e742f11ab12db68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen&lt;/div&gt;`)[0];
#             popup_fae6749efe4689ddfe62c877ed677144.setContent(html_916f58b97abdd0e68e742f11ab12db68);
#
#
#         marker_84073ed39d2adda164bbf85c34e48c81.bindPopup(popup_fae6749efe4689ddfe62c877ed677144)
#         ;
#
#
#
#
#             var marker_e40660e180cc593fcb0163b85896d050 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_e839543a1d3028de28b41ec125ba304a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6e7077947041c424b20df01ffbe404da = $(`&lt;div id=&quot;html_6e7077947041c424b20df01ffbe404da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal&lt;/div&gt;`)[0];
#             popup_e839543a1d3028de28b41ec125ba304a.setContent(html_6e7077947041c424b20df01ffbe404da);
#
#
#         marker_e40660e180cc593fcb0163b85896d050.bindPopup(popup_e839543a1d3028de28b41ec125ba304a)
#         ;
#
#
#
#
#             var marker_6480123403130cb2d2e7cf71b4e0f1f5 = L.marker(
#                 [38.94574889, -104.5698933],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_c474639ea892cc2ecdbf3381b087b89a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0b97a918a157d955322308c927d42743 = $(`&lt;div id=&quot;html_0b97a918a157d955322308c927d42743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake&lt;/div&gt;`)[0];
#             popup_c474639ea892cc2ecdbf3381b087b89a.setContent(html_0b97a918a157d955322308c927d42743);
#
#
#         marker_6480123403130cb2d2e7cf71b4e0f1f5.bindPopup(popup_c474639ea892cc2ecdbf3381b087b89a)
#         ;
#
#
#
#
#             var marker_e8e46b8679d6ecd3d733c4ae50949760 = L.marker(
#                 [42.74134667, -78.05208056],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_3342629102a93324da5527c27de6b9cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f36fcf44266eeeae7ed5b0149b232589 = $(`&lt;div id=&quot;html_f36fcf44266eeeae7ed5b0149b232589&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw&lt;/div&gt;`)[0];
#             popup_3342629102a93324da5527c27de6b9cb.setContent(html_f36fcf44266eeeae7ed5b0149b232589);
#
#
#         marker_e8e46b8679d6ecd3d733c4ae50949760.bindPopup(popup_3342629102a93324da5527c27de6b9cb)
#         ;
#
#
#
#
#             var marker_37e048b760574f9b55c440fbf09479f0 = L.marker(
#                 [30.6880125, -81.90594389],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_4115a4691aab0e6bcfdf24ffd591748d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ac9b6cc01f0af4ccd46da83c17b67ed = $(`&lt;div id=&quot;html_3ac9b6cc01f0af4ccd46da83c17b67ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hilliard Airpark&lt;/div&gt;`)[0];
#             popup_4115a4691aab0e6bcfdf24ffd591748d.setContent(html_3ac9b6cc01f0af4ccd46da83c17b67ed);
#
#
#         marker_37e048b760574f9b55c440fbf09479f0.bindPopup(popup_4115a4691aab0e6bcfdf24ffd591748d)
#         ;
#
#
#
#
#             var marker_f3b8298677c20f432858c04284d8c921 = L.marker(
#                 [34.49166667, -88.20111111],
#                 {}
#             ).addTo(map_1ac8b1d7f73db6216996e2e88a532c29);
#
#
#         var popup_289569e3e0a4f140c88954dc104ecfee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_812e0f75ec0f5de906110e89a22cda4a = $(`&lt;div id=&quot;html_812e0f75ec0f5de90

# %%
# multiple markers using dictionary

markers_dict = {'Los Angeles': [34.041008, -118.246653], 
                'Las Vegas': [36.169726, -115.143996], 
                'Denver': [39.739448, -104.992450], 
                'Chicago': [41.878765, -87.643267], 
                'Manhattan': [40.782949, -73.969559]}

# create map
map_cities = folium.Map(location=[41, -99], zoom_start=4)

# plot locations
for i in markers_dict.items():
    folium.Marker(location=i[1], popup=i[0]).add_to(map_cities)
    print(i)

# display map    
map_cities
# Out:
# ('Los Angeles', [34.041008, -118.246653])
# ('Las Vegas', [36.169726, -115.143996])
# ('Denver', [39.739448, -104.99245])
# ('Chicago', [41.878765, -87.643267])
# ('Manhattan', [40.782949, -73.969559])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0c1b05ea3743194a269c1528f1b1308 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0c1b05ea3743194a269c1528f1b1308&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f0c1b05ea3743194a269c1528f1b1308 = L.map(
#                 &quot;map_f0c1b05ea3743194a269c1528f1b1308&quot;,
#                 {
#                     center: [41.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e77a0287fdee8152da6ce27ae3cc52b8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#             var marker_1b1b1fdc6f1b60609f61e24b695c8946 = L.marker(
#                 [34.041008, -118.246653],
#                 {}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#         var popup_975b42cfd20def043a9035777f87b58f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_89e35277fd44c820c3a189728abb46d0 = $(`&lt;div id=&quot;html_89e35277fd44c820c3a189728abb46d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#             popup_975b42cfd20def043a9035777f87b58f.setContent(html_89e35277fd44c820c3a189728abb46d0);
#
#
#         marker_1b1b1fdc6f1b60609f61e24b695c8946.bindPopup(popup_975b42cfd20def043a9035777f87b58f)
#         ;
#
#
#
#
#             var marker_643be74be77b115a49db60559fe079ea = L.marker(
#                 [36.169726, -115.143996],
#                 {}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#         var popup_da12a2db22d3a49a274601650b2457ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_794056cd19a789e28403214d4e9fee12 = $(`&lt;div id=&quot;html_794056cd19a789e28403214d4e9fee12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#             popup_da12a2db22d3a49a274601650b2457ae.setContent(html_794056cd19a789e28403214d4e9fee12);
#
#
#         marker_643be74be77b115a49db60559fe079ea.bindPopup(popup_da12a2db22d3a49a274601650b2457ae)
#         ;
#
#
#
#
#             var marker_6c2b67c323cd68b4e8c7b7c727fc2d84 = L.marker(
#                 [39.739448, -104.99245],
#                 {}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#         var popup_1971e9c08ee228fda952d7830e9d0725 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_41993a93a9e46fa48b91f7fa28d0e8d5 = $(`&lt;div id=&quot;html_41993a93a9e46fa48b91f7fa28d0e8d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#             popup_1971e9c08ee228fda952d7830e9d0725.setContent(html_41993a93a9e46fa48b91f7fa28d0e8d5);
#
#
#         marker_6c2b67c323cd68b4e8c7b7c727fc2d84.bindPopup(popup_1971e9c08ee228fda952d7830e9d0725)
#         ;
#
#
#
#
#             var marker_bdd0f6eec654a6e6426686ddd60a4489 = L.marker(
#                 [41.878765, -87.643267],
#                 {}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#         var popup_3c517e17fab25ea0b9a94209c90300a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_10aabe7cb5dd4106393b25e0148b74bf = $(`&lt;div id=&quot;html_10aabe7cb5dd4106393b25e0148b74bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago&lt;/div&gt;`)[0];
#             popup_3c517e17fab25ea0b9a94209c90300a5.setContent(html_10aabe7cb5dd4106393b25e0148b74bf);
#
#
#         marker_bdd0f6eec654a6e6426686ddd60a4489.bindPopup(popup_3c517e17fab25ea0b9a94209c90300a5)
#         ;
#
#
#
#
#             var marker_d44692fe75d48afca1384be7bb931f94 = L.marker(
#                 [40.782949, -73.969559],
#                 {}
#             ).addTo(map_f0c1b05ea3743194a269c1528f1b1308);
#
#
#         var popup_546213241470bfb71fcdb9c14f30ebbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_525dbb1284ffa807de5b297e0d740abe = $(`&lt;div id=&quot;html_525dbb1284ffa807de5b297e0d740abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#             popup_546213241470bfb71fcdb9c14f30ebbb.setContent(html_525dbb1284ffa807de5b297e0d740abe);
#
#
#         marker_d44692fe75d48afca1384be7bb931f94.bindPopup(popup_546213241470bfb71fcdb9c14f30ebbb)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search for 'font awesome' icons to see examples

# map
map_cm_fa = folium.Map(location=[38, -98], zoom_start=4)

# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(color='green', icon='bolt', prefix='fa')).add_to(map_cm_fa)

# display map
map_cm_fa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56aa5fa2afce6e32036a3953af9a4459 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56aa5fa2afce6e32036a3953af9a4459&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_56aa5fa2afce6e32036a3953af9a4459 = L.map(
#                 &quot;map_56aa5fa2afce6e32036a3953af9a4459&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4730d84464f6e799cae52bacf1c3f6a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56aa5fa2afce6e32036a3953af9a4459);
#
#
#             var marker_f6229760adb44963863e8ccb26cdcee7 = L.marker(
#                 [38.0, -98.0],
#                 {}
#             ).addTo(map_56aa5fa2afce6e32036a3953af9a4459);
#
#
#             var icon_7cdd0c96184145bf6682cb190d9f0de6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bolt&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f6229760adb44963863e8ccb26cdcee7.setIcon(icon_7cdd0c96184145bf6682cb190d9f0de6);
#
#
#         var popup_f27936fb3e07da747eeec679623d9af6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f4538e419f808d171fe980698695bb1b = $(`&lt;div id=&quot;html_f4538e419f808d171fe980698695bb1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#             popup_f27936fb3e07da747eeec679623d9af6.setContent(html_f4538e419f808d171fe980698695bb1b);
#
#
#         marker_f6229760adb44963863e8ccb26cdcee7.bindPopup(popup_f27936fb3e07da747eeec679623d9af6)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search for 'glyphicon bootstrap' icons to see examples

# map
map_cm_glyphicon = folium.Map(location=[38, -98], zoom_start=4)

# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(icon='glyphicon-plane', prefix='glyphicon')).add_to(map_cm_glyphicon)

# display map
map_cm_glyphicon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b39b86dedc4ebc497b7472ad3da8bbba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b39b86dedc4ebc497b7472ad3da8bbba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b39b86dedc4ebc497b7472ad3da8bbba = L.map(
#                 &quot;map_b39b86dedc4ebc497b7472ad3da8bbba&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d19df1123bf4690b4bc07b6e9df62c3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b39b86dedc4ebc497b7472ad3da8bbba);
#
#
#             var marker_7cfde5a776b7cb35083ff4a47b71189b = L.marker(
#                 [38.0, -98.0],
#                 {}
#             ).addTo(map_b39b86dedc4ebc497b7472ad3da8bbba);
#
#
#             var icon_c0c3709d0698173c6d089807f4d394e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7cfde5a776b7cb35083ff4a47b71189b.setIcon(icon_c0c3709d0698173c6d089807f4d394e7);
#
#
#         var popup_64ee452a1a68002a6bb9c944bae4536a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_55c807b30c912c34dad3f9d03ffd270b = $(`&lt;div id=&quot;html_55c807b30c912c34dad3f9d03ffd270b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#             popup_64ee452a1a68002a6bb9c944bae4536a.setContent(html_55c807b30c912c34dad3f9d03ffd270b);
#
#
#         marker_7cfde5a776b7cb35083ff4a47b71189b.bindPopup(popup_64ee452a1a68002a6bb9c944bae4536a)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# multiple custom markers

# dataframe with custom marker names
cm_df = pd.DataFrame({'city': ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan'],
                      'latitude': [34.041008, 36.169726, 39.739448, 41.878765, 40.782949],
                      'longitude': [-118.246653, -115.143996, -104.992450, -87.643267, -73.969559],
                      'icon': ['bicycle', 'car', 'bus', 'truck', 'motorcycle']})
cm_df
# Out:
#           city   latitude   longitude        icon
# 0  Los Angeles  34.041008 -118.246653     bicycle
# 1    Las Vegas  36.169726 -115.143996         car
# 2       Denver  39.739448 -104.992450         bus
# 3      Chicago  41.878765  -87.643267       truck
# 4    Manhattan  40.782949  -73.969559  motorcycle

# %%
# map
map_cm_multiple = folium.Map(location=[38, -98], zoom_start=4)

# add markers to map
# for loop with itertuples (experiment that appears to work well)
# can also use iterrows or dataframe apply
for i in cm_df.itertuples():
    folium.Marker(location=[i.latitude, i.longitude], 
                  popup=i.city,
                  icon=folium.Icon(icon=i.icon, prefix='fa')).add_to(map_cm_multiple)

# display map    
map_cm_multiple
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42d03e4365780e9f799ebbb03deb3853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42d03e4365780e9f799ebbb03deb3853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42d03e4365780e9f799ebbb03deb3853 = L.map(
#                 &quot;map_42d03e4365780e9f799ebbb03deb3853&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77a74061115f127c7bcdb4628f9db96d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42d03e4365780e9f799ebbb03deb3853);
#
#
#             var marker_bca0a08e67c8f881cfc3063a4596dee3 = L.marker(
#                 [34.041008, -118.246653],
#                 {}
#             ).addTo(map_42d03e4365780e9f799ebbb03deb3853);
#
#
#             var icon_217f80db3b546d38613251d69b4113ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bca0a08e67c8f881cfc3063a4596dee3.setIcon(icon_217f80db3b546d38613251d69b4113ae);
#
#
#         var popup_4bdfe69fb6763646ddbf435fed9bb5bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1447043eed725c452b2f5dc35ba602da = $(`&lt;div id=&quot;html_1447043eed725c452b2f5dc35ba602da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#             popup_4bdfe69fb6763646ddbf435fed9bb5bd.setContent(html_1447043eed725c452b2f5dc35ba602da);
#
#
#         marker_bca0a08e67c8f881cfc3063a4596dee3.bindPopup(popup_4bdfe69fb6763646ddbf435fed9bb5bd)
#         ;
#
#
#
#
#             var marker_e09e253b3aa84e16c5ce5354d72a695e = L.marker(
#                 [36.169726, -115.143996],
#                 {}
#             ).addTo(map_42d03e4365780e9f799ebbb03deb3853);
#
#
#             var icon_a20c4100565925df4eb8af1e14cb5c62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e09e253b3aa84e16c5ce5354d72a695e.setIcon(icon_a20c4100565925df4eb8af1e14cb5c62);
#
#
#         var popup_6f630f40050c06cdd9f4d03b6188f0ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_60d175a8216a704a980672aae2b43bb3 = $(`&lt;div id=&quot;html_60d175a8216a704a980672aae2b43bb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#             popup_6f630f40050c06cdd9f4d03b6188f0ac.setContent(html_60d175a8216a704a980672aae2b43bb3);
#
#
#         marker_e09e253b3aa84e16c5ce5354d72a695e.bindPopup(popup_6f630f40050c06cdd9f4d03b6188f0ac)
#         ;
#
#
#
#
#             var marker_a0abdb7afa5ae6a10d82754d326d728d = L.marker(
#                 [39.739448, -104.99245],
#                 {}
#             ).addTo(map_42d03e4365780e9f799ebbb03deb3853);
#
#
#             var icon_43f5815c60fb531e2e06da103ea5c7c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a0abdb7afa5ae6a10d82754d326d728d.setIcon(icon_43f5815c60fb531e2e06da103ea5c7c2);
#
#
#         var popup_fb8244ceb721b02c2ecb793ba862baee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7776d48f7eb94a55724f5711b6ab75f2 = $(`&lt;div id=&quot;html_7776d48f7eb94a55724f5711b6ab75f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#             popup_fb8244ceb721b02c2ecb793ba862baee.setContent(html_7776d48f7eb94a55724f5711b6ab75f2);
#
#
#         marker_a0abdb7afa5ae6a10d82754d326d728d.bindPopup(popup_fb8244ceb721b02c2ecb793ba862baee)
#         ;
#
#
#
#
#             var marker_e53623a84a24ceb26038343b7c97200a = L.marker(
#                 [41.878765, -87.643267],
#                 {}
#             ).addTo(map_42d03e4365780e9f799ebbb03deb3853);
#
#
#             var icon_12225044c54bf79c6ffbefd95fd8ef56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;truck&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e53623a84a24ceb26038343b7c97200a.setIcon(icon_12225044c54bf79c6ffbefd95fd8ef56);
#
#
#         var popup_9021fa6936b7f

# %%
# route

# map
map_plot_route = folium.Map(location=[38, -98], zoom_start=4)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route_lats_longs = [[34.041008,-118.246653],
                    [36.169726,-115.143996], 
                    [39.739448,-104.992450], 
                    [41.878765,-87.643267], 
                    [40.782949,-73.969559]]

# add route to map
folium.PolyLine(route_lats_longs).add_to(map_plot_route)

# display map
map_plot_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_962c5a4e9f16cd1138987817cdb37834 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_962c5a4e9f16cd1138987817cdb37834&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_962c5a4e9f16cd1138987817cdb37834 = L.map(
#                 &quot;map_962c5a4e9f16cd1138987817cdb37834&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e48c4bec0944ebbdf458ff2a3369717 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_962c5a4e9f16cd1138987817cdb37834);
#
#
#             var poly_line_e9e96a0b81aa4cee04b1cd79f448e63f = L.polyline(
#                 [[34.041008, -118.246653], [36.169726, -115.143996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_962c5a4e9f16cd1138987817cdb37834);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ant path route
# uses import - from folium import plugins

# map
map_ant_route = folium.Map(location=[38, -98], zoom_start=4)

# add ant path route to map
plugins.AntPath(route_lats_longs).add_to(map_ant_route)

# display map
map_ant_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c42d73602b35f03420c48649a7ac2ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c42d73602b35f03420c48649a7ac2ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c42d73602b35f03420c48649a7ac2ac4 = L.map(
#                 &quot;map_c42d73602b35f03420c48649a7ac2ac4&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6dca7f3b82e5d4189b141cfef1e7dd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c42d73602b35f03420c48649a7ac2ac4);
#
#
#             ant_path_78493dc48d8135f9ce42d16e68950afc = L.polyline.antPath(
#               [[34.041008, -118.246653], [36.169726, -115.143996], [39.739448, -104.99245], [41.878765, -87.643267], [40.782949, -73.969559]],
#               {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0000FF&quot;, &quot;dashArray&quot;: [10, 20], &quot;dashOffset&quot;: null, &quot;delay&quot;: 400, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;hardwareAcceleration&quot;: false, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;paused&quot;: false, &quot;pulseColor&quot;: &quot;#FFFFFF&quot;, &quot;reverse&quot;: false, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#         ).addTo(map_c42d73602b35f03420c48649a7ac2ac4);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Overlay GeoJSON Layers

# %%
# use a link or file
# use geojson.io to create custom geojson files
# can also use folium Draw control to create geojson files (example below)
# convert shapefiles to geojson using QGIS

# map
map_geojson = folium.Map(location=[39.77, -86.15], zoom_start=7)

# add geojson file to map
folium.GeoJson('indiana_outline_map.geojson', name='geojson indiana').add_to(map_geojson)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_geojson)

# display map
map_geojson
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [23], in <cell line: 10>()
#       7 map_geojson = folium.Map(location=[39.77, -86.15], zoom_start=7)
#       9 # add geojson file to map
# ---> 10 folium.GeoJson('indiana_outline_map.geojson', name='geojson indiana').add_to(map_geojson)
#      12 # add layer control to map (allows layer to be turned on or off)
#      13 folium.LayerControl().add_to(map_geojson)
#
# File ~\anaconda3\envs\mapenv\lib\site-packages\folium\features.py:499, in GeoJson.__init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     496         raise TypeError("Only Marker, Circle, and CircleMarker are supported as GeoJson marker types.")
#     497 self.marker = marker
# --> 499 self.data = self.process_data(data)
#     501 if self.style or self.highlight:
#     502     self.convert_to_feature_collection()
#
# File ~\anaconda3\envs\mapenv\lib\site-packages\folium\features.py:536, in GeoJson.process_data(self, data)
#     534         if not self.embed:
#     535             self.embed_link = data
# --> 536         with open(data) as f:
#     537             return json.loads(f.read())
#     538 elif hasattr(data, '__geo_interface__'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'indiana_outline_map.geojson'
